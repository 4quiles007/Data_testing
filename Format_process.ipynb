# %% [markdown]
# El primer paso es desacargar las cartolas y exienten 2 principalmente

# %%
#### LIBRERIAS Y CONFIGS GLOBALES
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

############ FUNCTION ################

# Define una función para recorrer el DataFrame y mostrar el contenido de cada celda y eliminar basura a nivel fila
def iterar_filas_columnas(root_file,num_files):
    df = pd.read_excel(f'{root_file}{num_files}.xls')
    max_row_to_delete= list()
    for i, fila in enumerate(df.index):
        lista_valores_fila = list()
        for j, columna in enumerate(df.columns):
            contenido_celda = df.loc[fila, columna]
            lista_valores_fila.append(contenido_celda)
        if  all(pd.isna(elemento) for elemento in lista_valores_fila):
            max_row_to_delete.append(fila)
    df.drop(max_row_to_delete,inplace=True)
    return df

def drop_columns_nan(root_file,num_files):   ## deja un dataframe solo con valores , eliminando basura
    df2 = iterar_filas_columnas(root_file,num_files)
    for columna in df2.columns:
        # Verifica si todos los valores en la columna son nulos
        if df2[columna].isnull().all():
            # Elimina la columna si todos los valores son nulos
            df2.drop(columna, axis=1, inplace=True)
    df2.reset_index(drop=True,inplace=True)  # resetear índice de filas
    df2.columns = range(df2.shape[1])  # resetear índice de columnas
    return df2

def data_table_format(root_file,num_files):
    a,b = root_file,num_files
    df2 = drop_columns_nan(a,b)
    headers_values = []
    expected_headers = ['Fecha', 'Descripción', 'Canal o Sucursal', 'Cargos (CLP)', 'Abonos (CLP)', 'Saldo (CLP)'] ### cuales son los headers a dejar 
    deleted_rows_not_table = 0 ## almacena hasta donde se va a eliminar datos que no son propios de la tabla de datos
    for indice, fila in df2.iterrows():
        valores_fila = fila.tolist()
        # Comparación insensible a mayúsculas y minúsculas y sin espacios adicionales
        valores_fila_strip = [valor.strip().lower() if isinstance(valor, str) else valor for valor in valores_fila]
        if valores_fila_strip == [header.lower() for header in expected_headers]:
            headers_values.append(valores_fila)
            deleted_rows_not_table = indice
            df2.drop(list(range(deleted_rows_not_table)),inplace=True) ## elimina hasta el valor de indice que cohincide con el header esperado
            print(f'Eliminar filas hasta la fila: {deleted_rows_not_table}')
    nuevos_encabezados = df2.iloc[0] 
    df2.rename(columns=nuevos_encabezados,inplace = True)  # Establecer los nuevos encabezados de columna
    df2.drop(df2.index[0], inplace=True)
    df2.reset_index(drop=True,inplace=True)
    df2.drop(df2.index[-1], inplace=True)  ## eliminar la ultima fila innecesaria de datos
    return df2

root_file = 'cartola_parte_'
num_files = 1 

data1 = data_table_format(root_file,1)
data2 = data_table_format(root_file,2)
data3 = data_table_format(root_file,3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 #### LIBRERIAS Y CONFIGS GLOBALES
# ----> 2 import pandas as pd
#       3 pd.set_option('display.max_rows', None)
#       4 pd.set_option('display.max_columns', None)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
##ordenar df por fecha 

data1['Fecha'] = pd.to_datetime(data1['Fecha'],format='%d/%m/%Y')
data1['Fecha'] = data1['Fecha'].dt.strftime('%d-%m-%Y')
data1 = data1.sort_values(by='Fecha')
data2['Fecha'] = pd.to_datetime(data2['Fecha'],format='%d/%m/%Y')
data2['Fecha'] = data2['Fecha'].dt.strftime('%d-%m-%Y')
data2 = data2.sort_values(by='Fecha')
data3['Fecha'] = pd.to_datetime(data3['Fecha'],format='%d/%m/%Y')
data3['Fecha'] = data3['Fecha'].dt.strftime('%d-%m-%Y')
data3 = data3.sort_values(by='Fecha')
data_global_operation = pd.concat([data1,data2,data3])

# %%
df_reset = data_global_operation.reset_index(drop=True)
# Exportar el DataFrame reseteado a un archivo Excel
# Puedes especificar el nombre del archivo que deseas crear
nombre_archivo_excel = 'cartola_cuenta_corriente.xlsx'
df_reset.to_excel(nombre_archivo_excel, index=False,)
data_global_operation
# Out:
#          Fecha                           Descripción    Canal o Sucursal  \
# 33  01-02-2024     Traspaso A:Gonzalo Alonso Gomez G            Internet
# 37  01-02-2024     Traspaso A:Hans Cristian Jeria Di            Internet
# 36  01-02-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 35  01-02-2024                Pago:express Irarrazav  Of. El Belloto Op.
# 34  01-02-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 92  02-01-2024    Traspaso De:Gerson Patricio Zu?nti            Internet
# 87  02-01-2024        Traspaso De:Claudio David Sanz            Internet
# 88  02-01-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 89  02-01-2024                     Cargo Por Pago Tc            Internet
# 90  02-01-2024                   Pago:little Caesars  Of. El Belloto Op.
# 93  02-01-2024                Pago:hiper Lider San J  Of. El Belloto Op.
# 91  02-01-2024                Pago:hiper Lider San J  Of. El Belloto Op.
# 32  02-02-2024           Traspaso A:Ricardo Huilipan            Internet
# 85  03-01-2024                 Pago:oxxo Metro Nunoa  Of. El Belloto Op.
# 86  03-01-2024      Traspaso A:Oscar Ricardo Morales            Internet
# 80  04-01-2024     Traspaso A:Ana Carolina Santander            Internet
# 81  04-01-2024     Traspaso A:Ana Carolina Santander            Internet
# 82  04-01-2024               Traspaso A:Khipu Clbs B            Internet
# 83  04-01-2024  Recaudacion Y Pagos De Servicios   *     Oficina Central
# 84  04-01-2024       Traspaso A:Medio De Pago Fintoc            Internet
# 79  04-01-2024     Traspaso A:Ana Carolina Santander            Internet
# 30  05-02-2024                Pago:express Irarrazav  Of. El Belloto Op.
# 29  05-02-2024                Pago:iris Flor Quezada  Of. El Belloto Op.
# 28  05-02-2024                    Pago:almacen Samue  Of. El Belloto Op.
# 31  05-02-2024                Pago:jmg Gastronomia L  Of. El Belloto Op.
# 25  06-02-2024                          Pago:fabiola  Of. El Belloto Op.
# 26  06-02-2024                   Pago:little Caesars  Of. El Belloto Op.
# 27  06-02-2024     Traspaso A:Ana Carolina Santander            Internet
# 23  07-02-2024                Pago:express Irarrazav  Of. El Belloto Op.
# 22  07-02-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 24  07-02-2024           Traspaso A:Ricardo Huilipan            Internet
# 77  08-01-2024      Traspaso De:Aida Cecilia Sanchez            Internet
# 76  08-01-2024           Traspaso A:Ricardo Huilipan            Internet
# 78  08-01-2024                         Pago:aguavida  Of. El Belloto Op.
# 19  08-02-2024               Traspaso A:Khipu Clbs B            Internet
# 21  08-02-2024                       Pago:san Camilo  Of. El Belloto Op.
# 20  08-02-2024                Pago:claro Recaudacion  Of. El Belloto Op.
# 18  08-02-2024  Recaudacion Y Pagos De Servicios   *     Oficina Central
# 17  08-02-2024              Traspaso A:Aguas Andinas            Internet
# 16  08-02-2024                Pago:metrogas Metrogas  Of. El Belloto Op.
# 15  08-02-2024                   Pago:usm Portal Web  Of. El Belloto Op.
# 75  09-01-2024                Pago:hiper Lider San J  Of. El Belloto Op.
# 74  10-01-2024      Cargo Seguro Proteccion Bancaria     Oficina Central
# 73  12-01-2024                            Pago:yinki  Of. El Belloto Op.
# 12  12-02-2024                  Pago:parque Brasil 1  Of. El Belloto Op.
# 13  12-02-2024      Cargo Seguro Proteccion Bancaria     Oficina Central
# 14  12-02-2024              Traspaso A:Pedro Miranda            Internet
# 9   12-02-2024                           Pago:tuttis  Of. El Belloto Op.
# 10  12-02-2024  Giro Cajero Automatico             *  Of. El Belloto Op.
# 11  12-02-2024                 Pago:fegal Restaurant  Of. El Belloto Op.
# 7   13-02-2024                    Traspaso A:Movired            Internet
# 8   13-02-2024             Traspaso A:Santiago Reiny            Internet
# 5   14-02-2024                 Pago:decathlon Costan  Of. El Belloto Op.
# 3   14-02-2024                  Pago:ripley Debito R  Of. El Belloto Op.
# 4   14-02-2024                      Pago:big O Pizza  Of. El Belloto Op.
# 6   14-02-2024                Pago:hym Costanera Cen  Of. El Belloto Op.
# 2   14-02-2024           Traspaso A:Ricardo Huilipan            Internet
# 65  15-01-2024       Traspaso A:Medio De Pago Fintoc            Internet
# 72  15-01-2024     Traspaso A:Felipe Francisco Pared            Internet
# 71  15-01-2024                 Pago:wendy S Vespucio  Of. El Belloto Op.
# 70  15-01-2024                Pago:hip Lider Plaza V  Of. El Belloto Op.
# 69  15-01-2024  Giro Cajero Automatico             *  Of. El Belloto Op.
# 68  15-01-2024                       Pago:beit- Jala  Of. El Belloto Op.
# 67  15-01-2024                    Pago:mp *papa John  Of. El Belloto Op.
# 63  15-01-2024                Pago:jumbo Florida Cen  Of. El Belloto Op.
# 64  15-01-2024                 Pago:saxoline Florida  Of. El Belloto Op.
# 66  15-01-2024                Pago:kelos San Joaquin  Of. El Belloto Op.
# 0   15-02-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 1   15-02-2024                   Pago:dulce Pola Spa  Of. El Belloto Op.
# 62  16-01-2024               Traspaso A:Khipu Clbs B            Internet
# 61  18-01-2024                Pago:cafeteria Viva Es  Of. El Belloto Op.
# 60  19-01-2024                  Pago:starbucks Coffe  Of. El Belloto Op.
# 59  22-01-2024                Pago:hiper Lider San J  Of. El Belloto Op.
# 58  22-01-2024     Traspaso A:Ana Carolina Santander            Internet
# 57  23-01-2024                     Pago:nanos Coffee  Of. El Belloto Op.
# 56  23-01-2024                Pago:cafeteria Viva Es  Of. El Belloto Op.
# 55  23-01-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 54  24-01-2024                 Traspaso A:Yilan Hipp            Internet
# 53  24-01-2024            Traspaso De:Acciona360 Spa            Internet
# 52  24-01-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 49  25-01-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 51  25-01-2024                    Traspaso A:Movired            Internet
# 50  25-01-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 48  26-01-2024                Pago:mc Donalds Provid  Of. El Belloto Op.
# 47  29-01-2024                Pago:kioskos Kfc San J  Of. El Belloto Op.
# 45  29-01-2024                 Pago:ekono Laguna Sur  Of. El Belloto Op.
# 44  29-01-2024     Traspaso De:Nicolas Ignacio Araya            Internet
# 46  29-01-2024                Pago:kelos San Joaquin  Of. El Belloto Op.
# 43  30-01-2024               Traspaso De:Mosaico S A            Internet
# 42  30-01-2024                     Cargo Por Pago Tc            Internet
# 41  31-01-2024                Pago:c Verde Irarrazav  Of. El Belloto Op.
# 40  31-01-2024                    Traspaso A:Movired            Internet
# 39  31-01-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 38  31-01-2024                Pago:comedor De Vitali  Of. El Belloto Op.
# 49  01-03-2024                Pago:comercial Cristia  Of. El Belloto Op.
# 48  01-03-2024                    Pago:almacen Samue  Of. El Belloto Op.
# 43  04-03-2024                Pago:claro Recaudacion  Of. El Belloto Op.
# 47  04-03-2024                  Pago:hip Lider Nunoa  Of. El Belloto Op.
# 46  04-03-2024                    Traspaso A:Movired            Internet
# 45  04-03-2024                   Pago:neko Papeleria  Of. El Belloto Op.
# 44  04-03-2024                       Pago:san Camilo  Of. El Belloto Op.
# 36  05-03-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 37  05-03-2024     Traspaso A:Ana Carolina Santander            Internet
# 38  05-03-2024     Traspaso A:Daniela Carolina Inost            Internet
# 39  05-03-2024             Traspaso A:Zugeidy Ortega            Internet
# 35  05-03-2024           Traspaso A:Ricardo Huilipan            Internet
# 41  05-03-2024               Traspaso A:Khipu Clbs B            Internet
# 42  05-03-2024  Recaudacion Y Pagos De Servicios   *     Oficina Central
# 40  05-03-2024                Pago:metrogas Metrogas  Of. El Belloto Op.
# 33  06-03-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 34  06-03-2024                Pago:express Irarrazav  Of. El Belloto Op.
# 30  07-03-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 32  07-03-2024                       Pago:san Camilo  Of. El Belloto Op.
# 31  07-03-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 29  08-03-2024                Pago:sumup * Capax Spa  Of. El Belloto Op.
# 23  11-03-2024                Pago:casa Ideas Florid  Of. El Belloto Op.
# 24  11-03-2024       Traspaso A:Teresa Ramos Morgana            Internet
# 25  11-03-2024               Traspaso A:Jose Caceres            Internet
# 26  11-03-2024                 Pago:santa Isabel Pte  Of. El Belloto Op.
# 27  11-03-2024  Giro Cajero Automatico             *  Of. El Belloto Op.
# 28  11-03-2024      Cargo Seguro Proteccion Bancaria     Oficina Central
# 20  12-03-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 21  12-03-2024                    Traspaso A:Movired            Internet
# 22  12-03-2024            Traspaso A:Bryan Arancibia            Internet
# 19  13-03-2024                Pago:merpago*productos  Of. El Belloto Op.
# 85  16-02-2024                Pago:doc Popcorn Costa  Of. El Belloto Op.
# 86  16-02-2024                 Pago:ripley Costanera  Of. El Belloto Op.
# 87  16-02-2024                Pago:zara Costanera Ce  Of. El Belloto Op.
# 17  18-03-2024                Pago:kelos San Joaquin  Of. El Belloto Op.
# 16  18-03-2024                Pago:lider.cl Webpay M  Of. El Belloto Op.
# 18  18-03-2024                Pago:abastos Internaci  Of. El Belloto Op.
# 77  19-02-2024                Pago:kelos San Joaquin  Of. El Belloto Op.
# 78  19-02-2024              Traspaso A:Eduardo Silva            Internet
# 80  19-02-2024                           Pago:tuttis  Of. El Belloto Op.
# 81  19-02-2024                           Pago:tuttis  Of. El Belloto Op.
# 82  19-02-2024                Pago:kelos San Joaquin  Of. El Belloto Op.
# 83  19-02-2024              Traspaso A:Alejandro Sea            Internet
# 84  19-02-2024                Pago:inversiones Y Com  Of. El Belloto Op.
# 79  19-02-2024                Pago:sta Isabel La Flo  Of. El Belloto Op.
# 15  19-03-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 14  19-03-2024     Traspaso A:Hans Cristian Jeria Di            Internet
# 74  20-02-2024                Pago:cafeteria Viva Es  Of. El Belloto Op.
# 73  20-02-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 76  20-02-2024     Traspaso A:Condominio Espacio Tre            Internet
# 75  20-02-2024                 Pago:merpago*ruta Del  Of. El Belloto Op.
# 10  20-03-2024                            Pago:maxik  Of. El Belloto Op.
# 11  20-03-2024                       Pago:pomona Spa  Of. El Belloto Op.
# 12  20-03-2024                Pago:merpago*productos  Of. El Belloto Op.
# 13  20-03-2024                    Traspaso A:Movired            Internet
# 70  21-02-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 69  21-02-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 68  21-02-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 72  21-02-2024        Traspaso De:Claudio David Sanz            Internet
# 71  21-02-2024     Traspaso De:Carlos Andres Navarro            Internet
# 9   21-03-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 8   21-03-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 63  22-02-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 64  22-02-2024                   Pago:kfc La Fabrica  Of. El Belloto Op.
# 65  22-02-2024                    Traspaso A:Movired            Internet
# 66  22-02-2024                Pago:comercial Gparada  Of. El Belloto Op.
# 67  22-02-2024                Pago:mario Tapia Elgue  Of. El Belloto Op.
# 7   22-03-2024                Pago:doc Popcorn Costa  Of. El Belloto Op.
# 6   22-03-2024                Pago:pasteleria San Pa  Of. El Belloto Op.
# 61  23-02-2024     Traspaso A:Hans Cristian Jeria Di            Internet
# 62  23-02-2024                        Pago:tanta Spa  Of. El Belloto Op.
# 4   25-03-2024               Pago Tarjeta De Credito            Internet
# 5   25-03-2024                Pago:usm Sj Caja/casin  Of. El Belloto Op.
# 60  26-02-2024     Traspaso A:Daniela Carolina Inost            Internet
# 58  26-02-2024                Pago:gladys Angela Mun  Of. El Belloto Op.
# 57  26-02-2024                Pago:almacen Sol De Or  Of. El Belloto Op.
# 56  26-02-2024                  Pago:delicious Beach  Of. El Belloto Op.
# 59  26-02-2024        Traspaso De:Lucas Daniel Gomez            Internet
# 2   26-03-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 3   26-03-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 55  27-02-2024    Traspaso De:Sebastian Alejandro Al            Internet
# 54  27-02-2024                Pago:cafeteria Viva Es  Of. El Belloto Op.
# 53  27-02-2024               Traspaso A:Claudio Sanz            Internet
# 1   27-03-2024               Traspaso De:Mosaico S A            Internet
# 0   27-03-2024                Pago:tienda - Costaner  Of. El Belloto Op.
# 52  28-02-2024               Traspaso De:Mosaico S A            Internet
# 51  29-02-2024                     Cargo Por Pago Tc            Internet
# 50  29-02-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 39  01-04-2024                Pago:sumup * Aulamusic  Of. El Belloto Op.
# 35  01-04-2024           Traspaso A:Fintual Agf S.a.            Internet
# 38  01-04-2024                  Pago:mt Aut Nunoa L6  Of. El Belloto Op.
# 37  01-04-2024     Traspaso A:Ana Carolina Santander            Internet
# 36  01-04-2024                     Cargo Por Pago Tc            Internet
# 34  03-04-2024                     Pago:el Container  Of. El Belloto Op.
# 33  04-04-2024                 Pago:merpago*ruta Del  Of. El Belloto Op.
# 32  04-04-2024                     Pago:studio Lions  Of. El Belloto Op.
# 29  05-04-2024             Traspaso A:Cristobal Labe            Internet
# 31  05-04-2024             Traspaso A:Dulce Pola Spa            Internet
# 30  05-04-2024           Traspaso A:Ricardo Huilipan            Internet
# 20  08-04-2024  Giro Cajero Automatico             *  Of. El Belloto Op.
# 28  08-04-2024                Pago:sumup * Aulamusic  Of. El Belloto Op.
# 26  08-04-2024              Traspaso A:Aguas Andinas            Internet
# 25  08-04-2024                Pago:tommy Beans Flori  Of. El Belloto Op.
# 24  08-04-2024                   Pago:florida Center  Of. El Belloto Op.
# 23  08-04-2024                Pago:easy Florida Cent  Of. El Belloto Op.
# 22  08-04-2024                Pago:merpago*maria Ver  Of. El Belloto Op.
# 21  08-04-2024                 Pago:wendy S Vespucio  Of. El Belloto Op.
# 27  08-04-2024  Recaudacion Y Pagos De Servicios   *     Oficina Central
# 19  08-04-2024               Traspaso A:Khipu Clbs B            Internet
# 18  08-04-2024               Traspaso A:Khipu Clbs B            Internet
# 17  09-04-2024                            Pago:maxik  Of. El Belloto Op.
# 16  09-04-2024                Pago:cinepolis La Rein  Of. El Belloto Op.
# 15  09-04-2024                Pago:merpago*autoservi  Of. El Belloto Op.
# 14  09-04-2024     Traspaso A:Ana Carolina Santander            Internet
# 13  10-04-2024                       Pago:pomona Spa  Of. El Belloto Op.
# 12  10-04-2024                Pago:express Irarrazav  Of. El Belloto Op.
# 11  10-04-2024      Cargo Seguro Proteccion Bancaria     Oficina Central
# 10  11-04-2024                Pago:kioskos Kfc San J  Of. El Belloto Op.
# 9   12-04-2024                Pago:jmg Gastronomia L  Of. El Belloto Op.
# 8   15-04-2024                Pago:kelos San Joaquin  Of. El Belloto Op.
# 7   15-04-2024                        Pago:jose Jara  Of. El Belloto Op.
# 6   17-04-2024                Pago:mt Aut Los Leones  Of. El Belloto Op.
# 5   17-04-2024  Traspaso De:Hans Cristian Jeria Diaz            Internet
# 4   17-04-2024                Pago:metrogas Metrogas  Of. El Belloto Op.
# 3   18-04-2024                              Pago:wei  Of. El Belloto Op.
# 2   19-04-2024                   Pago:dulce Pola Spa  Of. El Belloto Op.
# 1   19-04-2024                Pago:express Pd Valdiv  Of. El Belloto Op.
# 0   19-04-2024                Pago:carlos Andres Dia  Of. El Belloto Op.
#
#    Cargos (CLP) Abonos (CLP) Saldo (CLP)
# 33        17004          NaN      871291
# 37        12498          NaN      893810
# 36         1400          NaN      892410
# 35         2515          NaN      889895
# 34         1600          NaN      888295
# 92          NaN        27000     1041420
# 87          NaN         6900      576038
# 88        13800          NaN      569138
# 89       422922          NaN      582938
# 90        26000          NaN     1005860
# 93       118910          NaN     1014420
# 91         9560          NaN     1031860
# 32        19099          NaN      852192
# 85         2300          NaN      568738
# 86         5000          NaN      571038
# 80        86270          NaN      308481
# 81       122500          NaN      394751
# 82        14989          NaN      517251
# 83        26498          NaN      532240
# 84        10000          NaN      558738
# 79         2500          NaN      305981
# 30        11810          NaN      825763
# 29         1000          NaN      824763
# 28         7960          NaN      816803
# 31        14619          NaN      837573
# 25         1800          NaN      684503
# 26         8000          NaN      686303
# 27       122500          NaN      694303
# 23        11320          NaN      653603
# 22         3000          NaN      650603
# 24        19580          NaN      664923
# 77          NaN        90000      389981
# 76         4278          NaN      385703
# 78         6000          NaN      299981
# 19        14989          NaN      626404
# 21         2780          NaN      647823
# 20         6430          NaN      641393
# 18        25172          NaN      601232
# 17         3440          NaN      597792
# 16         7849          NaN      589943
# 15        96143          NaN      493800
# 75        19430          NaN      366273
# 74         2949          NaN      363324
# 73         2800          NaN      360524
# 12         8000          NaN      478764
# 13         2936          NaN      486764
# 14         4100          NaN      489700
# 9          1500          NaN      455414
# 10        20000          NaN      456914
# 11         1850          NaN      476914
# 7         10000          NaN      435414
# 8         10000          NaN      445414
# 5          6000          NaN      408424
# 3         77960          NaN      324964
# 4          5500          NaN      402924
# 6         20990          NaN      414424
# 2         11500          NaN      313464
# 65        10000          NaN      213874
# 72        11500          NaN      349024
# 71        11690          NaN      337334
# 70        17990          NaN      319344
# 69        50000          NaN      269344
# 68        12600          NaN      256744
# 67        29970          NaN      226774
# 63        40378          NaN      138506
# 64        34990          NaN      178884
# 66         2900          NaN      223874
# 0          3500          NaN      306564
# 1          3400          NaN      310064
# 62         6430          NaN      132076
# 61         5200          NaN      126876
# 60         2800          NaN      124076
# 59        31198          NaN       92878
# 58        65000          NaN       27878
# 57         1200          NaN       26678
# 56         2700          NaN       23978
# 55         5400          NaN       18578
# 54         3100          NaN       15478
# 53          NaN        92115      107593
# 52         3500          NaN      104093
# 49         5400          NaN       92093
# 51         5000          NaN       99093
# 50         1600          NaN       97493
# 48         9790          NaN       82303
# 47         9990          NaN       72313
# 45         4780          NaN       63258
# 44          NaN         6000       69258
# 46         4275          NaN       68038
# 43          NaN      1100655     1169913
# 42       238229          NaN      931684
# 41         3576          NaN      928108
# 40        15000          NaN      913108
# 39         1800          NaN      911308
# 38         5000          NaN      906308
# 49         8000          NaN      783888
# 48         3650          NaN      780238
# 43         7720          NaN      749948
# 47         6890          NaN      773348
# 46        10000          NaN      763348
# 45         3000          NaN      760348
# 44         2680          NaN      757668
# 36         1800          NaN      649921
# 37        13747          NaN      651721
# 38        18500          NaN      665468
# 39         6000          NaN      683968
# 35        14994          NaN      634927
# 41        15336          NaN      702060
# 42        32552          NaN      717396
# 40        12092          NaN      689968
# 33         6600          NaN      617547
# 34        10780          NaN      624147
# 30         1400          NaN      611267
# 32         3280          NaN      614267
# 31         1600          NaN      612667
# 29         3580          NaN      607687
# 23         9990          NaN      545907
# 24        13450          NaN      555897
# 25         4500          NaN      569347
# 26        20884          NaN      573847
# 27        10000          NaN      594731
# 28         2956          NaN      604731
# 20         3000          NaN      502907
# 21        10000          NaN      505907
# 22        30000          NaN      515907
# 19         2080          NaN      500827
# 85         3990          NaN      266594
# 86        13990          NaN      270584
# 87        21990          NaN      284574
# 17         5066          NaN      494961
# 16        19220          NaN      475741
# 18          800          NaN      500027
# 77         3240          NaN      201389
# 78        10000          NaN      204629
# 80         4892          NaN      239550
# 81         1500          NaN      244442
# 82         9062          NaN      245942
# 83         4000          NaN      255004
# 84         7590          NaN      259004
# 79        24921          NaN      214629
# 15         3000          NaN      472741
# 14         4832          NaN      467909
# 74         2200          NaN       67191
# 73          643          NaN       66548
# 76       129098          NaN       72291
# 75         2900          NaN       69391
# 10          990          NaN      451009
# 11         2700          NaN      451999
# 12         3210          NaN      454699
# 13        10000          NaN      457909
# 70         2200          NaN       99348
# 69         1800          NaN       97548
# 68         5600          NaN       91948
# 72          NaN        15000       81548
# 71          NaN        20000      101548
# 9          1600          NaN      449409
# 8          3500          NaN      445909
# 63         3400          NaN       59158
# 64         9990          NaN       62558
# 65        10000          NaN       72548
# 66         2500          NaN       82548
# 67         6900          NaN       85048
# 7          4990          NaN      440919
# 6          2400          NaN      438519
# 61         9412          NaN       46846
# 62         2900          NaN       56258
# 4         81499          NaN      355920
# 5          1100          NaN      437419
# 60        25000          NaN       21846
# 58        16360          NaN       17486
# 57         3900          NaN       13586
# 56         3100          NaN       10486
# 59          NaN        12000       33846
# 2          8800          NaN      344920
# 3          2200          NaN      353720
# 55          NaN         6000       16486
# 54         2200          NaN       14286
# 53         2000          NaN       12286
# 1           NaN      1100724     1445644
# 0         19990          NaN     1425654
# 52          NaN      1100481     1112767
# 51       319079          NaN      793688
# 50         1800          NaN      791888
# 39        10000          NaN     1415654
# 35       350000          NaN      614110
# 38        10000          NaN     1405654
# 37        70521          NaN     1335133
# 36       371023          NaN      964110
# 34        51892          NaN      562218
# 33         3900          NaN      558318
# 32        12000          NaN      546318
# 29         8000          NaN      518923
# 31         2400          NaN      543918
# 30        16995          NaN      526923
# 20        10000          NaN      426878
# 28         7500          NaN      511423
# 26         1750          NaN      479838
# 25         7490          NaN      472348
# 24        11290          NaN      461058
# 23        10990          NaN      450068
# 22         6000          NaN      444068
# 21         7190          NaN      436878
# 27        29835          NaN      481588
# 19         6913          NaN      419965
# 18        15229          NaN      404736
# 17         2580          NaN      402156
# 16         5600          NaN      396556
# 15         2200          NaN      394356
# 14       151600          NaN      242756
# 13         3800          NaN      238956
# 12         2530          NaN      236426
# 11         2973          NaN      233453
# 10         5200          NaN      228253
# 9         56705          NaN      171548
# 8         10131          NaN      161417
# 7          2300          NaN      159117
# 6         10000          NaN      149117
# 5           NaN         9200      158317
# 4          8137          NaN      150180
# 3         45908          NaN      104272
# 2          1000          NaN       99792
# 1         10810          NaN       88982
# 0          3200          NaN       85782
